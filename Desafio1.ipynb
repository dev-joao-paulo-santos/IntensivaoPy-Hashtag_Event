# %%
import pandas as p

t = p.read_excel('DASHBOARD AULA PRÁTICA.xlsx', sheet_name='BD')
display(t)
print(t.info())

import plotly.express as px

for c in t.columns:
    graf = px.histogram(t, x=c, text_auto=True)
    graf.show()
# Out:
#              Unidade    NF    Cidade Entrega                 Transportadora  \
# 0           Curitiba  2974          NATAL-RN     CORREIO RÁPIDO TRANSPORTES
# 1          São Paulo  5360        VITÓRIA-ES  TRANSAMERICA TRANSPORTES LTDA
# 2     Belo Horizonte  2133   PORTO ALEGRE-RS          TRANSPORTADORA MATTOS
# 3     Rio de Janeiro  2988   PORTO ALEGRE-RS          TRANSPORTADORA MATTOS
# 4     Rio de Janeiro  4840        VITÓRIA-ES  TRANSAMERICA TRANSPORTES LTDA
# ...              ...   ...               ...                            ...
# 1526  Rio de Janeiro  4326          NATAL-RN     CORREIO RÁPIDO TRANSPORTES
# 1527  Rio de Janeiro  2535        VITÓRIA-ES  TRANSAMERICA TRANSPORTES LTDA
# 1528  Belo Horizonte  3589        VITÓRIA-ES  TRANSAMERICA TRANSPORTES LTDA
# 1529       São Paulo  8732   PORTO ALEGRE-RS          TRANSPORTADORA MATTOS
# 1530       São Paulo  5632  FLORIANÓPOLIS-SC       RIACHO LIMPO TRANSPORTES
#
# ...
